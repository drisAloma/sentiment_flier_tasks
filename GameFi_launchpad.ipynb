# %%
import pandas as pd
import numpy as np
import warnings
import time
import re

from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# %%
warnings.filterwarnings('ignore', category = DeprecationWarning)

# %%
options = Options()

options.add_argument("--disable-blink-features=AutomationControlled")
options.add_argument("--disable-gpu")
options.add_argument("--no-sandbox")
options.headless=True
options.add_argument("--window-size=1400,1600")

# %%
titles = []
token_info = []
presale_status = []
vesting_schedule = []

# %%
def open(link):
    try:
        browser.get(link)
    except:
        print('no internet connection')

# %%
def OpenProjectLink():
    open('https://gamefi.org/')
    
    time.sleep(5)
    
    find_length = len(browser.find_elements(by = 'xpath', value ='//div[@class = "cursor-pointer"]/img'))
    
    list_count = 2
    
    while (list_count < find_length):
        global titles, token_info, vesting_schedule, presale_status
        
        find = browser.find_elements(by = 'xpath', value ='//div[@class = "cursor-pointer"]/img')
        find[list_count].click()
        
        time.sleep(5)
        
        try:
            title = browser.find_element(by ='xpath', value = '//h2[@class = "font-semibold text-2xl font-casual capitalize my-2"]').text
            titles.append(title)
        except:
            titles.append("Not Found")
        
        try:
            info = browser.find_elements(by ='xpath', value = '//div[@class = "flex justify-between mb-4 items-center"]')
            for element in info:
                token_info.append(element.text)
        except:
            info.append('TBD')
            
            
        try:
            vesting = browser.find_elements(by ='xpath', value = '//span[@class = "text-gamefiDark-100 text-[13px]"]')
            for detail in vesting:
                vesting_schedule.append(detail.text)
        except:
            vesting_schedule.append('TBD')
            
        
        try:
            stat_1 = browser.find_element(by ='xpath', value = '//div[@class = "inline-flex gap-1 items-center text-sm"]').text
            stat_2 = browser.find_element(by ='xpath', value = '//div[@class = "flex gap-2 lg:gap-4 items-center justify-center"]').text
            status = stat_1+' '+stat_2
            status = status.replace('\n',' ')
            presale_status.append(status)
        except:
            presale_status.append('COMING SOON')
        
        #go back
        time.sleep(2)
        browser.back()
        if list_count == find_length-1:
            break
        list_count +=1
        
    return "scrapped"

# %%
browser = webdriver.Chrome(executable_path="C:\webdrivers\chromedriver.exe", options = options)
OpenProjectLink()
# Out:
# 'scrapped'

# %%
titles,token_info,vesting_schedule,presale_status
# Out:
# (['Monsterra IGO',
#   'Monsterra Community',
#   'OceanLand IGO',
#   'OceanLand Community',
#   'Codyfight IGO',
#   'Codyfight Community',
#   'Epic War IGO',
#   'Epic War Community',
#   'XANA IGO',
#   'XANA Community',
#   'Monsterra Event'],
#  ['Symbol\nMSTR',
#   'Token Price\n0.2 BUSD',
#   'Total Raise\n$130,000',
#   'Swap Amount\n650,000 MSTR',
#   'Token Network\nBNB Chain',
#   'IGO Network\nBNB Chain',
#   'Accepted Currency\nBUSD',
#   'Symbol\nMSTR',
#   'Token Price\n0.2 BUSD',
#   'Total Raise\n$1,000',
#   'Swap Amount\n5,000 MSTR',
#   'Token Network\nBNB Chain',
#   'IGO Network\nBNB Chain',
#   'Accepted Currency\nBUSD',
#   'Symbol\nOLAND',
#   'Token Price\n0.03 BUSD',
#   'Total Raise\n$285,000',
#   'Swap Amount\n9,500,000 OLAND',
#   'Token Network\nBNB Chain',
#   'IGO Network\nBNB Chain',
#   'Accepted Currency\nBUSD',
#   'Symbol\nOLAND',
#   'Token Price\n0.03 BUSD',
#   'Total Raise\n$3,000',
#   'Swap Amount\n100,000 OLAND',
#   'Token Network\nBNB Chain',
#   'IGO Network\nBNB Chain',
#   'Accepted Currency\nBUSD',
#   'Symbol\nCTOK',
#   'Token Price\n0.08 USDT',
#   'Total Raise\n$140,500',
#   'Swap Amount\n1,756,250 CTOK',
#   'Token Network\nEthereum',
#   'IGO Network\nEthereum',
#   'Accepted Currency\nUSDT',
#   'Symbol\nCTOK',
#   'Token Price\n0.08 USDT',
#   'Total Raise\n$2,000',
#   'Swap Amount\n25,000 CTOK',
#   'Token Network\nEthereum',
#   'IGO Network\nEthereum',
#   'Accepted Currency\nUSDT',
#   'Symbol\nEWAR',
#   'Token Price\n0.04 BUSD',
#   'Total Raise\n$197,000',
#   'Swap Amount\n4,925,000 EWAR',
#   'Token Network\nBNB Chain',
#   'IGO Network\nBNB Chain',
#   'Accepted Currency\nBUSD',
#   'Symbol\nEWAR',
#   'Token Price\n0.04 BUSD',
#   'Total Raise\n$3,000',
#   'Swap Amount\n75,000 EWAR',
#   'Token Network\nBNB Chain',
#   'IGO Network\nBNB Chain',
#   'Accepted Currency\nBUSD',
#   'Symbol\nXETA',
#   'Token Price\n0.05 BUSD',
#   'Total Raise\n$99,000',
#   'Swap Amount\n1,980,000 XETA',
#   'Token Network\nBNB Chain',
#   'IGO Network\nBNB Chain',
#   'Accepted Currency\nBUSD',
#   'Symbol\nXETA',
#   'Token Price\n0.05 BUSD',
#   'Total Raise\n$1,000',
#   'Swap Amount\n20,000 XETA',
#   'Token Network\nBNB Chain',
#   'IGO Network\nBNB Chain',
#   'Accepted Currency\nBUSD',
#   'Symbol\nMSTR',
#   'Token Price\n0.2 BUSD',
#   'Total Raise\n$6,500',
#   'Swap Amount\n32,500 MSTR',
#   'Token Network\nBNB Chain',
#   'IGO Network\nBNB Chain',
#   'Accepted Currency\nBUSD'],
#  ['10% at TGE, 1 months cliff then linear vesting over the next 3 months',
#   '10% at TGE, 1 months cliff then linear vesting over the next 3 months',
#   '25% unlocked, 75% released over 3 months equally',
#   '25% unlocked, 75% released over 3 months equally',
#   '10% unlock on TGE, 4.5% each month starting at month 5',
#   '10% unlock on TGE, 4.5% each month starting at month 5',
#   '20% TGE then linear monthly (10 months)',
#   '20% TGE then linear monthly (10 months)',
#   '20% at TGE, 3-month cliff, then quarterly over the next 15 month',
#   '20% at TGE, 3-month cliff, then quarterly over the next 15 month',
#   '10% at TGE, 1 months cliff then linear vesting over the next 3 months'],
#  ['COMING SOON',
#   'COMING SOON',
#   'WHITELIST ENDS IN 07 DAYS : 11 HOURS : 43 MINUTES : 38 SECONDS',
#   'WHITELIST ENDS IN 07 DAYS : 11 HOURS : 43 MINUTES : 28 SECONDS',
#   'COMING SOON',
#   'COMING SOON',
#   'COMING SOON',
#   'COMING SOON',
#   'COMING SOON',
#   'COMING SOON',
#   'COMING SOON'])

# %%
info = [re.sub('.+[a-zA-Z]*\\n','',item) for item in token_info]
new_list = np.array(info).reshape(-1,7)

details =pd.DataFrame(new_list, columns = ['Symbol','Token Price','Total Raise','Swap Amount','Token Network',
                                        'IGO Network','Accepted Currency'])
details['Project Name'] = titles
details['Vesting Schedule'] = vesting_schedule
details['Launch Status']= presale_status

details =  details[['Project Name','Symbol','Token Price','Total Raise','Swap Amount','Token Network',
                                        'IGO Network','Accepted Currency','Vesting Schedule','Launch Status']]

details
# Out:
#            Project Name Symbol Token Price Total Raise      Swap Amount  \
# 0         Monsterra IGO   MSTR    0.2 BUSD    $130,000     650,000 MSTR
# 1   Monsterra Community   MSTR    0.2 BUSD      $1,000       5,000 MSTR
# 2         OceanLand IGO  OLAND   0.03 BUSD    $285,000  9,500,000 OLAND
# 3   OceanLand Community  OLAND   0.03 BUSD      $3,000    100,000 OLAND
# 4         Codyfight IGO   CTOK   0.08 USDT    $140,500   1,756,250 CTOK
# 5   Codyfight Community   CTOK   0.08 USDT      $2,000      25,000 CTOK
# 6          Epic War IGO   EWAR   0.04 BUSD    $197,000   4,925,000 EWAR
# 7    Epic War Community   EWAR   0.04 BUSD      $3,000      75,000 EWAR
# 8              XANA IGO   XETA   0.05 BUSD     $99,000   1,980,000 XETA
# 9        XANA Community   XETA   0.05 BUSD      $1,000      20,000 XETA
# 10      Monsterra Event   MSTR    0.2 BUSD      $6,500      32,500 MSTR
#
#    Token Network IGO Network Accepted Currency  \
# 0      BNB Chain   BNB Chain              BUSD
# 1      BNB Chain   BNB Chain              BUSD
# 2      BNB Chain   BNB Chain              BUSD
# 3      BNB Chain   BNB Chain              BUSD
# 4       Ethereum    Ethereum              USDT
# 5       Ethereum    Ethereum              USDT
# 6      BNB Chain   BNB Chain              BUSD
# 7      BNB Chain   BNB Chain              BUSD
# 8      BNB Chain   BNB Chain              BUSD
# 9      BNB Chain   BNB Chain              BUSD
# 10     BNB Chain   BNB Chain              BUSD
#
#                                      Vesting Schedule  \
# 0   10% at TGE, 1 months cliff then linear vesting...
# 1   10% at TGE, 1 months cliff then linear vesting...
# 2    25% unlocked, 75% released over 3 months equally
# 3    25% unlocked, 75% released over 3 months equally
# 4   10% unlock on TGE, 4.5% each month starting at...
# 5   10% unlock on TGE, 4.5% each month starting at...
# 6             20% TGE then linear monthly (10 months)
# 7             20% TGE then linear monthly (10 months)
# 8   20% at TGE, 3-month cliff, then quarterly over...
# 9   20% at TGE, 3-month cliff, then quarterly over...
# 10  10% at TGE, 1 months cliff then linear vesting...
#
#                                         Launch Status
# 0                                         COMING SOON
# 1                                         COMING SOON
# 2   WHITELIST ENDS IN 07 DAYS : 11 HOURS : 43 MINU...
# 3   WHITELIST ENDS IN 07 DAYS : 11 HOURS : 43 MINU...
# 4                                         COMING SOON
# 5                                         COMING SOON
# 6                                         COMING SOON
# 7                                         COMING SOON
# 8                                         COMING SOON
# 9                                         COMING SOON
# 10                                        COMING SOON
